# %%
import numpy as np
import pandas as pd
import matplotlib as plt

# %%
df = pd.read_csv('sro_data_examples/danila_dance.txt')
df_filtered = df.query('Distance<1000')
df_filtered
# Out:
#      Distance  Time
# 1          98  1099
# 2         114  1107
# 3         118  1115
# 4         118  1123
# 5         115  1130
# 6          99  1137
# 8          98  1323
# 9         111  1330
# 11         91  1515
# 12         92  1522
# 13         92  1528
# 15         90  1713
# 16        115  1721
# 18        103  1907
# 20        107  2093
# 21        112  2101
# 22        114  2108
# 23        110  2115
# 24        111  2123
# 25        109  2130
# 27        107  2316
# 29        106  2501
# 30        115  2508
# 31        110  2516
# 32        109  2524
# 33        108  2531
# 34        109  2538
# 35        110  2546
# 37        107  2732
# 38        111  2739
# ..        ...   ...
# 250        78  7975
# 251        78  7982
# 252        78  7987
# 254        97  8173
# 256        83  8355
# 257        84  8360
# 258        84  8367
# 259        82  8373
# 261        65  8556
# 262        64  8561
# 263        63  8565
# 264        63  8570
# 265        63  8574
# ...

# %%
import matplotlib.pyplot as plt

# gca stands for 'get current axis'
ax = plt.gca()

df_filtered.plot(kind='line',x='Time',y='Distance',ax=ax)
plt.show()
